# %%
import json
from zoomus import ZoomClient

# %%
client = ZoomClient('https://stanford.zoom.us/j/4340648848', 'ngluu3LPjIFhKHr2g6ks3tKdxjeNT5zo')

user_list_response = client.user.list()

# %%
print(user_list_response.content)
# Out:
# b'{"code":200,"message":"Invalid api key or secret."}'

# %%
user_list = json.loads(user_list_response.content)

for user in user_list['users']:
    user_id = user['id']
    print(json.loads(client.meeting.list(user_id=user_id).content))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-00dfd8c14706> in <module>
#       1 user_list = json.loads(user_list_response.content)
#       2
# ----> 3 for user in user_list['users']:
#       4     user_id = user['id']
#       5     print(json.loads(client.meeting.list(user_id=user_id).content))
#
# KeyError: 'users'
